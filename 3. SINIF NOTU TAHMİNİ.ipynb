# %% [markdown]
# # 3. sınf notu tahmini

# %%
import pandas as pd

# %%
from pycaret.regression import*

# %%
df=pd.read_excel('Mat.csv')
# dosya okundu

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
setup(data=df,target='G3')
# Out:
# <style type="text/css">
# #T_74058_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_74058">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74058_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_74058_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74058_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74058_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_74058_row0_col1" class="data row0 col1" >5786</td>
#     </tr>
#     <tr>
#       <th id="T_74058_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74058_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_74058_row1_col1" class="data row1 col1" >G3</td>
#     </tr>
#     <tr>
#       <th id="T_74058_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_a7f3e th {
#   text-align: left;
# }
# ...

# %%
best_model=create_model('gbr')
# Out:
# <style type="text/css">
# #T_da142_row10_col0, #T_da142_row10_col1, #T_da142_row10_col2, #T_da142_row10_col3, #T_da142_row10_col4, #T_da142_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_da142">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da142_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_da142_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_da142_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_da142_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_da142_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_da142_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
import joblib

# %%
joblib.dump(best_model,'ogrenci_sinav3.joblib')
# Out:
# ['ogrenci_sinav3.joblib']

# %%
#source   zafer acar noları
